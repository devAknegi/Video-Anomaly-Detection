# %%
import Ipynb_importer
import cv2 as cv
import sys,os
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import Counter
from numba import jit
from image_preprocessing import cdi_process,calc_entropy
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %matplotlib inline
sns.set_style('darkgrid')

Home_os='C:/Users/Ankush Negi/Desktop/Video Anomaly Detection in Road Accidents/Dataset/video/'
negative_os=Home_os+'negative/'
positive_os=Home_os+'positive/'

# %%
video=os.listdir(negative_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
Intensity_list=[]
for i in video:
    start=0
    video_name=negative_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='HARRIS')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
video=os.listdir(positive_os)
#My_CDI=cdi_process.CDI_lib(cap,Threshold=True,mythold=[0,255])
P_Intensity_list=[]
for i in video:
    start=0
    video_name=positive_os+i
    cap = cv.VideoCapture(video_name)
    My_CDI=cdi_process.CDI_lib(cap,Threshold=False,mythold=[0,255])
    in_list=[]
    while 1:
        if start<=27:
            cdi,frame=My_CDI.CDI(start,methods='HARRIS')
            cdi=cv.normalize(cdi,None,0,255,cv.NORM_MINMAX)
            H=calc_entropy.entropy(cdi)
            in_list.append(H)
            cv.imshow('frame',frame)
            cv.imshow('cdi',cdi)
            k = cv.waitKey(1) 
            start+=1
            if k ==27:     
                break 
        else:
            break
    P_Intensity_list.append(in_list)
    cap.release()
cv.destroyAllWindows()

# %%
Combine_Entropy=Intensity_list+P_Intensity_list
# min_max_scaler =MinMaxScaler()
# for i in range(len(Combine_Entropy)):
#     Combine_Entropy[i] = ((min_max_scaler.fit_transform(np.array(Combine_Entropy[i]).reshape(-1,1)))).reshape(-1).tolist()
new_list=[]
for i in Combine_Entropy:
        str1 = ' '.join([str(x) for x in i])
        new_list.append(str1)

print(len(new_list))
# Out:
# 299

# %%
x = [0] * 198
y =[1]*101
z=x+y

# %%
#combine_dict={'entropy':new_list,'label':z}
combine_dict1={'entropy':new_list,'label':z}
df=pd.DataFrame(combine_dict1)

display(df)

y=df['label'].values
# Out:
#                                                entropy  label
# 0    0.09623293172276906 0.07987305231928155 0.1228...      0
# 1    0.3049522411420381 0.1468430874734466 0.330796...      0
# 2    0.32391063880417137 0.28414840266876673 0.2276...      0
# 3    0.32228139467337447 0.3695305463146815 0.21474...      0
# 4    0.32797161195709307 0.23934780940294478 0.3726...      0
# ..                                                 ...    ...
# 294  0.11346596438717668 0.07731693746330816 0.0807...      1
# 295  0.13636514303551933 0.12854484867665017 0.2324...      1
# 296  0.2552721519639268 0.14681238227166304 0.11737...      1
# 297  0.1450359694997793 0.14902908050247934 0.14463...      1
# 298  0.310817482678952 0.38394472610802455 0.285102...      1
#
# [299 rows x 2 columns]

# %%
data_df = df['entropy'].str.split(' ', expand=True)

data_df['Class'] =y
data_df.to_csv('C:/Users/Ankush Negi/Desktop/Video Anomaly Detection in Road Accidents/CSV/Harris.csv')
display(data_df)
# Out:
#                        0                    1                    2  \
# 0    0.09623293172276906  0.07987305231928155  0.12286797484516772
# 1     0.3049522411420381   0.1468430874734466  0.33079605057270167
# 2    0.32391063880417137  0.28414840266876673  0.22768532640459116
# 3    0.32228139467337447   0.3695305463146815  0.21474629727667452
# 4    0.32797161195709307  0.23934780940294478  0.37265695065259197
# ..                   ...                  ...                  ...
# 294  0.11346596438717668  0.07731693746330816  0.08077401784839947
# 295  0.13636514303551933  0.12854484867665017  0.23246832355801259
# 296   0.2552721519639268  0.14681238227166304  0.11737770285853279
# 297   0.1450359694997793  0.14902908050247934   0.1446390100729047
# 298    0.310817482678952  0.38394472610802455   0.2851025715252292
#
#                        3                     4                     5  \
# 0    0.11689682279247175   0.07247895127451029  0.057034254700790855
# 1     0.3024261204037283   0.23637643497872318   0.16642664490587353
# 2    0.30395321729317787    0.3336266263387748   0.32516250173814076
